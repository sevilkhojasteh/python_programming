# %% [markdown]
# - PyPi: the massive online database hosting free packages
# - pip: this is the command-line tool installed on your computer that talks to PyPi, downloads the packages and installs them
#
# pip install requests
#
# pip install requests==2.28.1
#
# pip uninstall requests
#
# pip list --> See everything you have installed
#
# pip show requests --> See details about a specific package
#
#
#
# - Basic conda commands
#
# conda create --name my_env python=3.10
#
# conda activate my_env
#
# conda intall numpy pandas
#
# conda deactivate

# %% [markdown]
# Becasue requirement.txt gets so messy everyone uses pyproject.toml
#
# Poetry is a modern toll built specifically to use pyproject.toml

# %%
pip install poetry
# Out:
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 2.8 MB/s  0:00:00a 0:00:01m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.5 MB/s  0:00:00
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 7.9 MB/s  0:00:00m 8.2 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/28 [poetry]8;5;237m━ 27/28 [poetry]s-toolbelt]
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# Note: you may need to restart the kernel to use updated packages.

# %%
# if you want to create a porject just write 
# poetry new name-project
