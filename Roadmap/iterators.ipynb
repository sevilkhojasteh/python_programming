# %% [markdown]
# When you write for item in my_list:
#
# python does twp thing:
# 1. calls iter(my_list)
# 2. calls next()

# %%
my_list = [1, 2, 3, 4]

# %%
my_iterator = iter(my_list)

# %%
print(next(my_iterator))
# Out:
# 3

# %%
class CountDown:
    def __init__(self, start):
        self.count = start
    def __iter__(self):
        return self

    def __next__(self):
        if self.count <= 0:
            raise StopIteration
        self.count -= 1
        return self.count + 1

# %%
timer = CountDown(3)
for number in timer:
    print(number)
# Out:
# 3
# 2
# 1
