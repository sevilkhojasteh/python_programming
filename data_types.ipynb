# %%
# list

[1, 2, "three", 4.0, True, None, [5, 6, 7], {"key": "value"}, (8, 9, 10), {1, 2, 3}]
# Out:
# [1,
#  2,
#  'three',
#  4.0,
#  True,
#  None,
#  [5, 6, 7],
#  {'key': 'value'},
#  (8, 9, 10),
#  {1, 2, 3}]

# %%
# tuple
(1, 2, "three", 4.0, True, None, [5, 6, 7], {"key": "value"}, (8, 9, 10), {1, 2, 3})
# tuple is similar to list but it is immutable, meaning that you cannot change its contents after it is created. You can create a tuple by using parentheses () instead of square brackets [].
# Out:
# (1,
#  2,
#  'three',
#  4.0,
#  True,
#  None,
#  [5, 6, 7],
#  {'key': 'value'},
#  (8, 9, 10),
#  {1, 2, 3})

# %%
# sets
{1, 2, 3, 4, 5}
# sets are unordered collections of unique elements. You can create a set by using curly braces {} or the set() constructor. Sets are useful for performing mathematical operations like union, intersection, and difference
# Out:
# {1, 2, 3, 4, 5}

# %%
{1, 1, 2, 2}
# Out:
# {1, 2}

# %%
# dictionaries
d = {"key1": "value1", "key2": "value2", "key3": "value3"}
# dictionaries are unordered collections of key-value pairs. You can create a dictionary by using curly braces {} and separating keys and values with a colon :. Dictionaries are useful for storing and retrieving data based on keys.

d
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %%
d["key1"]
# Out:
# 'value1'

# %%
d["value1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 d["value1"]
#
# KeyError: 'value1'
