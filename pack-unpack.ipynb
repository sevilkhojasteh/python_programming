# %%
# this is packing
t = (1, 2, 3)

# %%
# this is unpacking
x, y, z = t

# %%
x
# Out:
# 1

# %%
# if you write t = 1, 2, 3 this is my default a tuple

# %%
d = {'a': 1, 'b': 2, 'c': 3}

# %%
x, y, z = d

# %%
x
# Out:
# 'a'

# %%
t = (1, 2)

# %%
x, y, z =t
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x, y, z =t
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
t = (1, 2, 3)

# %%
x, y = t
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x, y = t
#
# ValueError: too many values to unpack (expected 2, got 3)
