# %%
# this is packing
t = (1, 2, 3)

# %%
# this is unpacking
x, y, z = t

# %%
x
# Out:
# 1

# %%
# if you write t = 1, 2, 3 this is my default a tuple

# %%
d = {'a': 1, 'b': 2, 'c': 3}

# %%
x, y, z = d

# %%
x
# Out:
# 'a'

# %%
t = (1, 2)

# %%
x, y, z =t
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x, y, z =t
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
t = (1, 2, 3)

# %%
x, y = t
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 x, y = t
#
# ValueError: too many values to unpack (expected 2, got 3)

# %%
numbers = 1, 2, 3, 4, 5, 6

# %%
# the * operator
first, second, *middle, last = numbers

# %%
middle
# Out:
# [3, 4, 5]

# %%
first, *rest = numbers

# %%
type(rest)
# Out:
# list

# %%
rest
# Out:
# [2, 3, 4, 5, 6]

# %%
_ = 3

# %%
_
# Out:
# 3

# %%
# There is a convention in programming the variable that you will not use you can use _

# %%
x, *_, z = numbers

# %%
x, _, z
# Out:
# (1, [2, 3, 4, 5], 6)

# %%
# dictionaries can be unpacked too
# it uses * or **
# the ** unpacks keys and values

# %%
# Two dictionaries representing two different students' grades
student_grades_1 = {'Math': 90, 'English': 92}
student_grades_2 = {'Science': 88, 'History': 94}

# %%
grades = {**student_grades_1, **student_grades_2}

# %%
grades
# Out:
# {'Math': 90, 'English': 92, 'Science': 88, 'History': 94}

# %%
def add(a, b):
    return a+b

# %%
input = (3, 4)
add(*input)
# Out:
# 7

# %%
d = {
    'a': 4,
    'b': 8
}

add(a=d['a'], b = d['b'])
# Out:
# 12

# %%
add(**d)
# Out:
# 12
