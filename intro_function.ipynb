# %%
x = [1, 2, 3]

# %%
# len(x) is a fucntion too
len(x)
# Out:
# 3

# %%
# Functions describes the world
# Function is used for DRY(Don't repeat yourself)
def add(a, b):
    return a+b

# %%
add(3, 4)
# Out:
# 7

# %%
def greet():
    print("Hello, world!")

# %%
greet()
# Out:
# Hello, world!
