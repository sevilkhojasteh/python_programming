# %%
# simple statment
x = 10
print(x)
# Out:
# 10

# %%
# compound statement
if x > 5:
    print('x is grated than 5')
# Out:
# x is grated than 5

# %%
a = 1
b = 2
# this is a code block
if a == 1:
    print(a)
    if b == 2:
        print(b)

print('end')
# Out:
# 1
# 2
# end

# %%
# The importance is readability
