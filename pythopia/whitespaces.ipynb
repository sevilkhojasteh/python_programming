# %%
x=3;y=12
print(x+y) # Output: 15
# Out:
# 15

# %%
a = ['foo', 'bar', 'baz']
print(a)
# Out:
# ['foo', 'bar', 'baz']

# %%
s = 'hello'     'world'

# %%
s
# Out:
# 'helloworld'

# %%
2 in [1, 2]
# Out:
# True

# %%
a = 1
if a == 1:
 print(a)
# Out:
# 1
