# %%
def great():
    print("Hello")

# %%
great()
# Out:
# Hello

# %%
great()
# Out:
# Hello

# %%
def square(number):
    """
    This fucntion squares any number
    """
    return number * number

# here number is parameter

# %%
square(4)
# Here 4 is argument
# Out:
# 16

# %%
a = square(2), square(3)

# %%
a
# Out:
# (4, 9)

# %%
type(a)
# Out:
# tuple

# %%
# Naming convention for Fucntions
# for functions you need to use snake case like variables

# %%
# How to call a function
# functionName(arguments)

# %%
# you can add the value of return inside the function
# you can not add the value of print inside the function outside of it
