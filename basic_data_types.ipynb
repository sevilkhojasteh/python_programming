# %%
# binary data 
0b10
# Out:
# 2

# %%
# octal data
0o10
# Out:
# 8

# %%
# hexadecimal data
0x10
# Out:
# 16

# %%
# floating point data
3.14
# Out:
# 3.14

# %%
# complex data
1 + 2j
# Out:
# (1+2j)

# %%
# string data
"Hello, World!"
# Out:
# 'Hello, World!'

# %%
"hello \'world"
# Out:
# "hello 'world"

# %%
# Some useful escape sequences
print("This is a new line\nThis is a tab\tThis is a backslash\\")
# Out:
# This is a new line
# This is a tab	This is a backslash\

# %%
print(r'This is a raw string\nThis will not be a new line\tThis will not be a tab\\')
# Out:
# This is a raw string\nThis will not be a new line\tThis will not be a tab\\

# %%
a =5 
b = 5
a==b
# Out:
# True

# %%
# two types of naming variables
my_variable = 10
MyVariable = 20

# first one is snake_case and second one is pascalCase
# snake_case is used for variables, while PascalCase is used for functions and classes.
