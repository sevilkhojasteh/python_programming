# %% [markdown]
# in OOB everything is considered an object, and each object has features and actions for example I am an object
#
# I have height, weight,... --> features
#
# I can walk, talk, code, ... --> actions
