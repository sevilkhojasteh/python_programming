# %%
x = 5

# %%
names = [
    'a', 
    'b', 
    'c'
]

# %%
# Break
for name in names:
    print(name)
    if name == 'c':
        break
# Out:
# a
# b
# c

# %%
# Continue
for i in range(1, 10):
    if i == 5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9

# %%
# Pass

for i in range(1, 10):
    if i == 5:
        pass #TODO: add line later
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
