# %%
class Car:
    def __init__(self):
        print("calling init")
    def honk(self):
        print("car is honking")

# %%
obj = Car()

# %%
obj.x = 10

# %%
class Car:
    # class attribute
    wheels = 4
    # dunder method
    def __init__(self, model, year):
        self.model = model
        self.year = year

    # instance method
    def honk(self):
        print(f"{self.model} is honking")

# %%
obj = Car("Toyota", 2026)

# %%
obj.honk()
# Out:
# Toyota is honking

# %%
obj.wheels
# Out:
# 4

# %%
Car.wheels
# Out:
# 4

# %%
Car.wheels = 8

# %%
obj.wheels
# Out:
# 8
