# %% [markdown]
# **Core concepts of OOP**
#
# Everything is object which belongs to a class
#
# for example class is car, and all the car brands are objects are the class
#
# Each object has some attribute--> Features, Property--> color, speed, #seats
#
# and method, which are the features of the objects--> running, burning oil

# %%
class Dog:
    # These def are called mtehod and they all have self as the first attribute
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def bark(self):
        return f"{self.name} says Woof!"
    def sleep(self):
        return f"{self.name} is sleeping!"

# %%
dog1 = Dog('Max', 3)
dog2 = Dog('Sam', 10)

# %%
Dog.bark(dog1)
# Out:
# 'Max says Woof!'

# %%
dog1.name
# Out:
# 'Max'

# %%
dog1.age
# Out:
# 3

# %%
# Encapsulation
class Account:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.__balance = balance

    def deposite(self, amount):
        self.__balance += amount
        print(f"Added {amount} to the balance.")

    def show_balance(self):
        print(f"Balance: {self.__balance}")

    def withdraw(self, amount):
        if amount > self.__balance:
            print("Not enough balance")
        
        else:
            self.__balance += amount
            print(f"Balance: {self.__balance}")

# %%
class Animal:
    def speak(self):
        print("Animals speaks")

class Dog(Animal):
    def walk(self):
        print("Dog is walking")

class Bird(Animal):
    def fly(self):
        print("Bird is flying")

# %%
dog = Dog()
