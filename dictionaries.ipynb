# %%
my_dict = {
    'name': 'sevil',
    'age': 24, 
    'country': 'France',
    'language': 'Persian',
    'city': 'Paris'
}

# %%
my_dict['name']
# Out:
# 'sevil'

# %%
my_dict = {}

# %%
l = dict(
    [
        ('nika', 16),
        ('ali', 30), 
        ('Sarina', 28)
    ]
)
l
# Out:
# {'nika': 16, 'ali': 30, 'Sarina': 28}

# %%
dict(nika=16, sarina=18)
# Out:
# {'nika': 16, 'sarina': 18}

# %%
my_dict = {
    'name': 'sevil',
    'age': 24, 
    'country': 'France',
    'language': 'Persian',
    'city': 'Paris'
}

# %%
my_dict.get("city")
# Out:
# 'Paris'

# %%
my_dict.get('person')

# %%
my_dict.get('major', 'EE')
# Out:
# 'EE'

# %%
# .keys(), .values(), .items()

my_dict.keys()
# Out:
# dict_keys(['name', 'age', 'country', 'language', 'city'])

# %%
my_dict.values()
# Out:
# dict_values(['sevil', 24, 'France', 'Persian', 'Paris'])

# %%
my_dict.items()
# Out:
# dict_items([('name', 'sevil'), ('age', 24), ('country', 'France'), ('language', 'Persian'), ('city', 'Paris')])

# %%
my_dict['major'] = 'EE'

# %%
my_dict
# Out:
# {'name': 'sevil',
#  'age': 24,
#  'country': 'France',
#  'language': 'Persian',
#  'city': 'Paris',
#  'major': 'EE'}

# %%
my_dict.update(
    {
        'language' : 'turkish',
        'other lang':'English'
    }
)

# %%
my_dict
# Out:
# {'name': 'sevil',
#  'age': 24,
#  'country': 'France',
#  'language': 'turkish',
#  'city': 'Paris',
#  'major': 'EE',
#  'other lang': 'English'}

# %%
my_dict.pop('city')
# Out:
# 'Paris'

# %%
my_dict
# Out:
# {'name': 'sevil',
#  'age': 24,
#  'country': 'France',
#  'language': 'turkish',
#  'major': 'EE',
#  'other lang': 'English'}

# %%
my_dict.popitem()
# Out:
# ('other lang', 'English')

# %%
my_dict = {'name': 'Jack', 'age': 26}

# %%
'name' in my_dict
# Out:
# True

# %%
sample_dict = {'a':1, 'b':2, 'c':3}
sample_dict.setdefault('b', 4)
sample_dict.setdefault('d', 4)

sample_dict
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
len(sample_dict)
# Out:
# 4

# %%
sorted(sample_dict)
# Out:
# ['a', 'b', 'c', 'd']

# %%
sorted(sample_dict.values())
# Out:
# [1, 2, 3, 4]

# %%
family_ages = {
    'parent1': {'name': 'John', 'age': 42},
    'parent2': {'name': 'Jane', 'age': 40},
    'child': {'name': 'Doe', 'age': 18}
}

# %%
family_ages['parent1']
# Out:
# {'name': 'John', 'age': 42}

# %%
family_ages['parent1']['age']
# Out:
# 42
